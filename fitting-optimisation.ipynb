# %%
import h5py
import numpy as np
import pandas as pd 
from scipy.optimize import curve_fit

import matplotlib.pyplot as plt
import seaborn as sns 
plt.rcParams["figure.figsize"] = [16,9]
sns.set_style('whitegrid')

GRID_SIZE = 0.06
LOWER_LAMBDA = 6472.5
UPPER_LAMBDA = 6740
PLOT_MASK = range(1475,1550)

# %%
hf_grid = h5py.File("/home/pravn/Dropbox/Masters/Research Data/wl_grid.h5", "r")
wl_grid = np.array(hf_grid["wl_grid"])

# %%
df = pd.read_csv("/home/pravn/Dropbox/Masters/Research Data/results.csv", index_col=0)

# %%
df.head()
# Out:
#         sobject_id  6561.00000000059  6561.060000000591  6561.120000000591  \
# 0  131116000501262          0.791232           0.799116           0.798513
# 1  131116001001379          1.016790           1.033717           1.039141
# 2  131118002401234          1.068419           1.064418           1.059543
# 3  131118002401396          0.854523           0.876311           0.909512
# 4  131118002901052          0.958085           0.961354           0.958334
#
#    6561.1800000005915  6561.240000000592  6561.300000000592  \
# 0            0.789936           0.770570           0.747840
# 1            1.053989           1.071330           1.068635
# 2            1.045539           1.045996           1.074062
# 3            0.926363           0.935885           0.954685
# 4            0.960897           0.960540           0.954966
#
#    6561.360000000593  6561.420000000593  6561.4800000005935  ...  label  \
# 0           0.750200           0.778579            0.805557  ...      1
# 1           1.053506           1.034933            1.029725  ...      2
# 2           1.101389           1.097221            1.074829  ...      4
# 3           0.921646           0.926053            0.934858  ...      2
# 4           0.951380           0.939908            0.923267  ...      2
#
#             star_id       teff      e_teff      logg    e_logg      fe_h  \
# 0  03303061-6824089  5848.8174  109.977853  4.243084  0.184408 -0.338275
# 1  04315418-5613335  4328.7964  118.017575  3.327391  0.198075  0.169383
# 2  04303269-5730244  3136.7622         NaN  4.396316       NaN       NaN
# 3  04354318-5738560  4815.8853  140.982633  3.473381  0.215505 -0.916787
# 4  05292291-5823105  5056.8890   84.699254  3.586107  0.183447 -0.459082
#
#      e_fe_h         ra        dec
# 0  0.134476  52.627905 -68.402358
# 1  0.128575  67.975753 -56.225897
# 2       NaN  67.635947 -57.506949
# 3  0.134253  68.930000 -57.648952
# 4  0.065107  82.345409 -58.386368
#
# [5 rows x 86 columns]

# %%
df.head()
# Out:
#         sobject_id  6561.00000000059  6561.060000000591  6561.120000000591  \
# 0  131116000501262          0.791232           0.799116           0.798513
# 1  131116001001379          1.016790           1.033717           1.039141
# 2  131118002401234          1.068419           1.064418           1.059543
# 3  131118002401396          0.854523           0.876311           0.909512
# 4  131118002901052          0.958085           0.961354           0.958334
#
#    6561.1800000005915  6561.240000000592  6561.300000000592  \
# 0            0.789936           0.770570           0.747840
# 1            1.053989           1.071330           1.068635
# 2            1.045539           1.045996           1.074062
# 3            0.926363           0.935885           0.954685
# 4            0.960897           0.960540           0.954966
#
#    6561.360000000593  6561.420000000593  6561.4800000005935  ...  label  \
# 0           0.750200           0.778579            0.805557  ...      1
# 1           1.053506           1.034933            1.029725  ...      2
# 2           1.101389           1.097221            1.074829  ...      4
# 3           0.921646           0.926053            0.934858  ...      2
# 4           0.951380           0.939908            0.923267  ...      2
#
#             star_id       teff      e_teff      logg    e_logg      fe_h  \
# 0  03303061-6824089  5848.8174  109.977853  4.243084  0.184408 -0.338275
# 1  04315418-5613335  4328.7964  118.017575  3.327391  0.198075  0.169383
# 2  04303269-5730244  3136.7622         NaN  4.396316       NaN       NaN
# 3  04354318-5738560  4815.8853  140.982633  3.473381  0.215505 -0.916787
# 4  05292291-5823105  5056.8890   84.699254  3.586107  0.183447 -0.459082
#
#      e_fe_h         ra        dec
# 0  0.134476  52.627905 -68.402358
# 1  0.128575  67.975753 -56.225897
# 2       NaN  67.635947 -57.506949
# 3  0.134253  68.930000 -57.648952
# 4  0.065107  82.345409 -58.386368
#
# [5 rows x 86 columns]

# %%
SAMPLE_INDEX = 98

# %%
Y = df.loc[SAMPLE_INDEX,"6561.00000000059":"6565.44000000062"].values
galah_id = df.loc[SAMPLE_INDEX, "sobject_id"]
x = wl_grid[PLOT_MASK]

# %%
plt.plot(wl_grid[PLOT_MASK], Y)
plt.axvline(x=6562.83, color='coral', label="Hα", alpha=0.7)
plt.axvline(x=wl_grid[PLOT_MASK][np.argmax(Y)], color='green', label="Max. local flux",alpha=0.7)
plt.xlabel("Wavelength ($\mathrm{\AA}$)", size=10)
plt.ylabel("Flux [norm.]", size=10)
plt.xlim(wl_grid[PLOT_MASK].min(), wl_grid[PLOT_MASK].max())
plt.legend()

# %%
def double_gaussian(x, a1, b1, c1, a2, b2, c2, a3):
    return a1*np.exp(-np.power(x - b1, 2)/(2*np.power(c1, 2))) + a2*np.exp(-np.power(x - b2, 2)/(2*np.power(c2, 2))) + (a3)

# %%
#pars, cov = curve_fit(f=double_gaussian, xdata=wl_grid[PLOT_MASK], ydata=Y, p0=[0.4, wl_grid[PLOT_MASK][np.argmin(Y)], 0.1, 1.2, wl_grid[PLOT_MASK][np.argmax(Y)], 0.0003, 1],
#pars, cov = curve_fit(f=double_gaussian, xdata=wl_grid[PLOT_MASK], ydata=Y, p0=[0.4, wl_grid[PLOT_MASK][np.argmin(Y)], 0.1, 1.2, wl_grid[PLOT_MASK][np.argmax(Y)], 0.0005, 1], #97
pars, cov = curve_fit(f=double_gaussian, xdata=wl_grid[PLOT_MASK], ydata=Y, p0=[-np.argmin(Y), wl_grid[PLOT_MASK][np.argmin(Y)], -((wl_grid[PLOT_MASK][np.argmin(Y)]-6561.5)/5), np.argmax(Y), wl_grid[PLOT_MASK][np.argmax(Y)], (wl_grid[PLOT_MASK][np.argmax(Y)]-6565.5)/5, 1], #98
bounds=((-np.inf,-np.inf,-np.inf,-np.inf,-np.inf,-np.inf),(np.inf,np.inf,np.inf,np.inf,np.inf,np.inf)))

# %%
a1 = pars[0]
b1 = pars[1]
c1 = pars[2]
a2 = pars[3]
b2 = pars[4]
c2 = pars[5]
a3 = pars[6]

#mu + 5*sigma = lambda

# %%
f1 = a1*np.exp(-np.power(x - b1, 2)/(2*np.power(c1, 2)))
f2 = a2*np.exp(-np.power(x - b2, 2)/(2*np.power(c2, 2))) + a3
Y_fit = f1 + f2

# %%
plt.plot(x, Y_fit, color='red', label="Gaussian Mixture Model")
plt.plot(x, Y, color='cornflowerblue', label="Data -"+str(galah_id))
plt.plot(x, f1, color='seagreen', label="Gaussian 1", alpha=0.4, linestyle="--")
plt.plot(x, f2, color='dodgerblue', label="Gaussian 2", alpha=0.4, linestyle="--")
plt.axvline(x=6562.83, color='coral', label="Hα", alpha=0.7)
plt.axvline(x=wl_grid[PLOT_MASK][np.argmax(Y)], color='green', label="Max. local flux",alpha=0.7)
plt.axvline(x=wl_grid[PLOT_MASK][np.argmin(Y)], color='gray', label="Min. local flux",alpha=0.7)
plt.xlabel("Wavelength ($\mathrm{\AA}$)", size=10)
plt.ylabel("Flux [norm.]", size=10)
plt.xlim(wl_grid[PLOT_MASK].min(), wl_grid[PLOT_MASK].max())
plt.legend()
print(galah_id)
# Out:
# 140117002101372

# %%
print(a1) 
print(b1)
print(c1) 
print(a2)
print(b2)
print(c2)
print(a3)
# Out:
# -0.749074876964356
# 6562.9697427689225
# -0.4866819469460702
# 0.5754332988790957
# 6564.977084794205
# -0.30272941537973014
# 0.8892458428080579

# %%
print(wl_grid[PLOT_MASK][np.argmin(Y)])
print(wl_grid[PLOT_MASK][np.argmax(Y)])
# Out:
# 6562.920000000603
# 6565.020000000617

# %%
from lmfit import minimize, Parameters

# %%
def residual(params, x, data, uncertainty):
    amp1 = params['amp1']
    mu1 = params['mu1']
    sigma1 = params['sigma1']

    amp2 = params['amp2']
    mu2 = params['mu2']
    sigma2 = params['sigma2']

    model = amp1*np.exp(-np.power(x - mu1, 2)/(2*np.power(sigma1, 2))) + 1 + amp2*np.exp(-np.power(x - mu2, 2)/(2*np.power(sigma2, 2)))

    return (data-model) / uncertainty

# %%
params = Parameters()

params.add('amp1', value=0.6)
params.add('mu1', value=wl_grid[PLOT_MASK][np.argmin(Y)])
params.add('sigma1', value=0.1)

params.add('amp2', value=0.4)
params.add('mu2', value=wl_grid[PLOT_MASK][np.argmax(Y)])
params.add('sigma2', value=0.07)

# %%
data = Y

# %%
X = wl_grid[PLOT_MASK]

# %%
out = minimize(residual, params, args=(x, data, uncertainty))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8030/501385768.py in <module>
# ----> 1 out = minimize(residual, params, args=(x, data, uncertainty))
#
# NameError: name 'uncertainty' is not defined

# %%
from lmfit.models import ExpressionModel

# %%
gmod = ExpressionModel("amp1*np.exp(-(x - mu1)**2/(2*sigma1**2))")

# %%
params = gmod.make_params(amp1=0.6, mu1=6562.7, sigma1=0.1)

# %%
y = gmod.eval(params, x=x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_8030/761252770.py in <module>
# ----> 1 y = gmod.eval(params, x=x)
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/lmfit/model.py in eval(self, params, **kwargs)
#     866
#     867         """
# --> 868         return self.func(**self.make_funcargs(params, kwargs))
#     869
#     870     @property
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/lmfit/models.py in _eval(**kwargs)
#    1494                 self.asteval.symtable[name] = val
#    1495             self.asteval.start_time = time.time()
# -> 1496             return self.asteval.run(self.astcode)
#    1497
#    1498         kws["nan_policy"] = nan_policy
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/asteval/asteval.py in run(self, node, expr, lineno, with_raise)
#     290         # recursive calls into this run method.
#     291         try:
# --> 292             ret = handler(node)
#     293             if isinstance(ret, enumerate):
#     294                 ret = list(ret)
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/asteval/asteval.py in on_module(self, node)
#     368         out = None
#     369         for tnode in node.body:
# --> 370             out = self.run(tnode)
#     371         return out
#     372
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/asteval/asteval.py in run(self, node, expr, lineno, with_raise)
#     290         # recursive calls into this run method.
#     291         try:
# --> 292             ret = handler(node)
#     293             if isinstance(ret, enumerate):
#     294                 ret = list(ret)
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/asteval/asteval.py in on_expr(self, node)
#     347     def on_expr(self, node):
#     348         """Expression."""
# --> 349         return self.run(node.value)  # ('value',)
#     350
#     351     def on_index(self, node):
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/asteval/asteval.py in run(self, node, expr, lineno, with_raise)
#     290         # recursive calls into this run method.
#     291         try:
# --> 292             ret = handler(node)
#     293             if isinstance(ret, enumerate):
#     294                 ret = list(ret)
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/asteval/asteval.py in on_binop(self, node)
#     562         """Binary operator."""
#     563         return op2func(node.op)(self.run(node.left),
# --> 564                                 self.run(node.right))
#     565
#     566     def on_boolop(self, node):    # ('op', 'values')
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/asteval/asteval.py in run(self, node, expr, lineno, with_raise)
#     290         # recursive calls into this run method.
#     291         try:
# --> 292             ret = handler(node)
#     293             if isinstance(ret, enumerate):
#     294                 ret = list(ret)
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/asteval/asteval.py in on_call(self, node)
#     714         """Function execution."""
#     715         #  ('func', 'args', 'keywords'. Py<3.5 has 'starargs' and 'kwargs' too)
# --> 716         func = self.run(node.func)
#     717         if not hasattr(func, '__call__') and not isinstance(func, type):
#     718             msg = "'%s' is not callable!!" % (func)
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/asteval/asteval.py in run(self, node, expr, lineno, with_raise)
#     290         # recursive calls into this run method.
#     291         try:
# --> 292             ret = handler(node)
#     293             if isinstance(ret, enumerate):
#     294                 ret = list(ret)
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/asteval/asteval.py in on_attribute(self, node)
#     500         # AttributeError or accessed unsafe attribute
#     501         msg = "no attribute '%s' for %s" % (node.attr, self.run(node.value))
# --> 502         self.raise_exception(node, exc=AttributeError, msg=msg)
#     503
#     504     def on_assign(self, node):    # ('targets', 'value')
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/asteval/asteval.py in raise_exception(self, node, exc, msg, expr, lineno)
#     242             except:
#     243                 exc = RuntimeError
# --> 244         raise exc(self.error_msg)
#     245
#     246     # main entry point for Ast node evaluation
#
# AttributeError: at expr='amp1*np.exp(-(x - mu1)**2/(2*sigma1**2))'

# %%
print(y)
# Out:
# None

# %%
result = gmod.fit(Y, x=X, amp1=0.6, mu1=6562.7, sigma1=0.1, amp2=0.09)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_8030/3459494211.py in <module>
# ----> 1 result = gmod.fit(Y, x=X, amp1=0.6, mu1=6562.7, sigma1=0.1, amp2=0.09)
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/lmfit/model.py in fit(self, data, params, weights, method, iter_cb, scale_covar, verbose, fit_kws, nan_policy, calc_covar, max_nfev, **kwargs)
#    1048                              nan_policy=self.nan_policy, calc_covar=calc_covar,
#    1049                              max_nfev=max_nfev, **fit_kws)
# -> 1050         output.fit(data=data, weights=weights)
#    1051         output.components = self.components
#    1052         return output
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/lmfit/model.py in fit(self, data, params, weights, method, nan_policy, **kwargs)
#    1403         self.userkws.update(kwargs)
#    1404         self.init_fit = self.model.eval(params=self.params, **self.userkws)
# -> 1405         _ret = self.minimize(method=self.method)
#    1406
#    1407         for attr in dir(_ret):
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/lmfit/minimizer.py in minimize(self, method, params, **kws)
#    2350                         val.lower().startswith(user_method)):
#    2351                     kwargs['method'] = val
# -> 2352         return function(**kwargs)
#    2353
#    2354
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/lmfit/minimizer.py in leastsq(self, params, max_nfev, **kws)
#    1687         result.call_kws = lskws
#    1688         try:
# -> 1689             lsout = scipy_leastsq(self.__residual, variables, **lskws)
#    1690         except AbortFitException:
#    1691             pass
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/scipy/optimize/minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     408     if not isinstance(args, tuple):
#     409         args = (args,)
# --> 410     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     411     m = shape[0]
#     412
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/scipy/optimize/minpack.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      22 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      23                 output_shape=None):
# ---> 24     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      25     if (output_shape is not None) and (shape(res) != output_shape):
#      26         if (output_shape[0] != 1):
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/lmfit/minimizer.py in __residual(self, fvars, apply_bounds_transformation)
#     585             raise AbortFitException(f"fit aborted: too many function evaluations {self.max_nfev}")
#     586
# --> 587         out = self.userfcn(params, *self.userargs, **self.userkws)
#     588
#     589         if callable(self.iter_cb):
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/lmfit/model.py in _residual(self, params, data, weights, **kwargs)
#     763         """
#     764         model = self.eval(params, **kwargs)
# --> 765         if self.nan_policy == 'raise' and not np.all(np.isfinite(model)):
#     766             msg = ('The model function generated NaN values and the fit '
#     767                    'aborted! Please check your model function and/or set '
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
from lmfit.models import GaussianModel

# %%
x = wl_grid[PLOT_MASK]
y = Y

# %%
mod = GaussianModel()

# %%
pars = mod.guess(y, x=x)
out = mod.fit(y, pars, x=x)

print(out.fit_report(min_correl=0.25))
# Out:
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 4146
#     # data points      = 75
#     # variables        = 3
#     chi-square         = 4.05816540
#     reduced chi-square = 0.05636341
#     Akaike info crit   = -212.756783
#     Bayesian info crit = -205.804319
# [[Variables]]
#     amplitude:  2.3503e+08 +/- 8.9745e+11 (381839.94%) (init = 6.928235)
#     center:     6957.97318 +/- 102270.553 (1469.83%) (init = 6563.509)
#     sigma:      73.7455103 +/- 9556.92244 (12959.33%) (init = 2.22)
#     fwhm:       173.657403 +/- 22504.8320 (12959.33%) == '2.3548200*sigma'
#     height:     1271455.36 +/- 4.6902e+09 (368880.66%) == '0.3989423*amplitude/max(1e-15, sigma)'
# [[Correlations]] (unreported correlations are < 0.250)
#     C(amplitude, center) = 1.000
#     C(center, sigma)     = 1.000
#     C(amplitude, sigma)  = 1.000

# %%
import numpy as np
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

from scipy.integrate import cumtrapz

def func( x, a, x0, sigma ):
    return a * np.exp( -( x - x0 )**2 / ( 2 * sigma**2 ) )
    
amplitude = -10
peak_width = 30
x_peak_loc = 160

# Generating clean data
xl = np.linspace( 0, 200, 1000 )
y0 = func( xl, amplitude, x_peak_loc, peak_width )

mn = 0
N = 0.2
std = np.sqrt( N )
noise2 = np.random.normal( mn, std, size=len( xl ) )
yl = y0 + noise2

"""
Most simple implementation of the linear fit of mu and sigma
"""
nul = yl - yl[0]

Sk = cumtrapz( yl, x=xl, initial=0 )
Tk = cumtrapz( xl * yl, x=xl, initial=0 )

MX = [
        [ np.dot( Sk, Sk ), np.dot( Sk, Tk ) ],
        [ np.dot( Sk, Tk ), np.dot( Tk, Tk ) ]
    ]
Vek = [ np.dot( nul, Sk ), np.dot( nul, Tk ) ]

res = np.dot( np.linalg.inv( MX ), Vek )
sig = np.sqrt( -1 / res[1] )
mu = res[0] * sig**2 
print( sig )
print( mu )
"""
Most simple linear fit of amplitude, probably not required but...hey.
"""
fk = func( xl, 1, mu, sig )
amp = np.dot( yl, fk ) / np.dot( fk, fk )
print( amp )
print( "probably quite close, already")

popt, pcov = curve_fit( func, xl, yl, p0=( sig, mu, amp ) ) 
print( popt )

fig = plt.figure( 1 )
ax = fig.add_subplot( 1, 1, 1 )
ax.plot( xl, y0, c='k', label="analytic function" )
ax.scatter( xl, yl, s=5, label="fake noisy data" )
ym = func( xl, *popt )
ax.plot( xl, ym, c='r', label="Best fit" )
ax.legend()
fig.savefig( "model_fit.png" )
plt.legend( loc="lower left" )
plt.xlabel( "v" )
plt.ylabel( "f(v)" )
plt.show()
# Out:
# 30.867231759879544
# 159.99737308817748
# -9.889521860206143
# probably quite close, already
# [-10.01156382 159.95204337 -30.00810427]
